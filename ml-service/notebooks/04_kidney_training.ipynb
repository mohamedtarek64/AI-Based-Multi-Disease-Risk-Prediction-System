# %% [markdown]
# # 🫘 Chronic Kidney Disease Prediction
#
# Model training for CKD Assessment using UCI-style data patterns.

# %%
import pandas as pd
from xgboost import XGBClassifier
import joblib

df = pd.read_csv('../data/raw/kidney_raw.csv')
print(f"Kidney Data Loaded: {len(df)} rows")
